# %% [markdown]
# # **Scrape and Analyze Job Listings for Data Analyst Roles**

# %%
# Install BeautifulSoup and requests (usually already available in Colab)
# !pip install beautifulsoup4

# Import libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re
from collections import Counter

print("Libraries imported successfully!")
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)
# Libraries imported successfully!

# %%
# URL of Internshala’s Data Analytics Internship listings
url = 'https://internshala.com/internships/data-analytics-internship'

# Headers to mimic a browser request
headers = {
    'User-Agent': 'Mozilla/5.0'
}

print("URL and headers are set!")
# Out:
# URL and headers are set!

# %%
# Send request to the website
response = requests.get(url, headers=headers)

# Parse the HTML content
soup = BeautifulSoup(response.content, 'html.parser')

print("Web page content loaded and parsed!")
# Out:
# Web page content loaded and parsed!

# %%
# Find all internship cards on the page
job_cards = soup.find_all('div', class_='individual_internship')

print(f"Found {len(job_cards)} internships on the page!")
# Out:
# Found 41 internships on the page!

# %%
internships = []

for i, job in enumerate(job_cards):
    # Re-inspecting the HTML structure for title, company, and location
    # It seems the title is within an h3 tag with class 'heading_4_5'
    title_element = job.find('h3', class_='heading_4_5')
    title = title_element.text.strip() if title_element else "N/A"
    print(f"Internship {i} Title: {title}") # Debug print

    # The company name is within an h4 tag with class 'heading_6'
    company_element = job.find('h4', class_='heading_6')
    company = company_element.text.strip() if company_element else "N/A"
    print(f"Internship {i} Company: {company}") # Debug print

    # The location is within a div with class 'item_body' and a tag with class 'location_link'
    location_div = job.find('div', class_='item_body')
    location_element = location_div.find('a', class_='location_link') if location_div else None
    location = location_element.text.strip() if location_element else "N/A"
    print(f"Internship {i} Location: {location}") # Debug print


    # The description is in a div with class 'other_detail_item' but the content seems inconsistent, let's try to get the first skill or key responsibility
    description_element = job.find('div', class_='other_detail_item')
    # Looking for a div with class 'item_body' which seems to contain the skills or responsibilities
    skills_element = description_element.find('div', class_='item_body') if description_element else None
    description = skills_element.text.strip() if skills_element else ""
    print(f"Internship {i} Description: {description[:50]}...") # Debug print

    internships.append({
        'Title': title,
        'Company': company,
        'Location': location,
        'Description': description
    })

print("Internship details extracted!")
# Out:
# Internship 0 Title: N/A
# Internship 0 Company: N/A
# Internship 0 Location: N/A
# Internship 0 Description: ...
# Internship 1 Title: N/A
# Internship 1 Company: N/A
# Internship 1 Location: N/A
# Internship 1 Description: ...
# Internship 2 Title: N/A
# Internship 2 Company: N/A
# Internship 2 Location: N/A
# Internship 2 Description: ...
# Internship 3 Title: N/A
# Internship 3 Company: N/A
# Internship 3 Location: N/A
# Internship 3 Description: ...
# Internship 4 Title: N/A
# Internship 4 Company: N/A
# Internship 4 Location: N/A
# Internship 4 Description: ...
# Internship 5 Title: N/A
# Internship 5 Company: N/A
# Internship 5 Location: N/A
# Internship 5 Description: ...
# Internship 6 Title: N/A
# Internship 6 Company: N/A
# Internship 6 Location: N/A
# Internship 6 Description: ...
# Internship 7 Title: N/A
# Internship 7 Company: N/A
# Internship 7 Location: N/A
# Internship 7 Description: ...
# Internship 8 Title: N/A
# Internship 8 Company: N/A
# Internship 8 Location: N/A
# Internship 8 Description: ...
# Internship 9 Title: N/A
# Internship 9 Company: N/A
# Internship 9 Location: N/A
# Internship 9 Description: ...
# Internship 10 Title: N/A
# Internship 10 Company: N/A
# Internship 10 Location: N/A
# Internship 10 Description: ...
# Internship 11 Title: N/A
# Internship 11 Company: N/A
# Internship 11 Location: N/A
# Internship 11 Description: ...
# Internship 12 Title: N/A
# Internship 12 Company: N/A
# Internship 12 Location: N/A
# Internship 12 Description: ...
# Internship 13 Title: N/A
# Internship 13 Company: N/A
# Internship 13 Location: N/A
# Internship 13 Description: ...
# Internship 14 Title: N/A
# Internship 14 Company: N/A
# Internship 14 Location: N/A
# Internship 14 Description: ...
# Internship 15 Title: N/A
# Internship 15 Company: N/A
# Internship 15 Location: N/A
# Internship 15 Description: ...
# Internship 16 Title: N/A
# Internship 16 Company: N/A
# Internship 16 Location: N/A
# Internship 16 Description: ...
# Internship 17 Title: N/A
# Internship 17 Company: N/A
# Internship 17 Location: N/A
# Internship 17 Description: ...
# Internship 18 Title: N/A
# Internship 18 Company: N/A
# Internship 18 Location: N/A
# Internship 18 Description: ...
# Internship 19 Title: N/A
# Internship 19 Company: N/A
# Internship 19 Location: N/A
# Internship 19 Description: ...
# Internship 20 Title: N/A
# Internship 20 Company: N/A
# Internship 20 Location: N/A
# Internship 20 Description: ...
# Internship 21 Title: N/A
# Internship 21 Company: N/A
# Internship 21 Location: N/A
# Internship 21 Description: ...
# Internship 22 Title: N/A
# Internship 22 Company: N/A
# Internship 22 Location: N/A
# Internship 22 Description: ...
# Internship 23 Title: N/A
# Internship 23 Company: N/A
# Internship 23 Location: N/A
# Internship 23 Description: ...
# Internship 24 Title: N/A
# Internship 24 Company: N/A
# Internship 24 Location: N/A
# Internship 24 Description: ...
# Internship 25 Title: N/A
# Internship 25 Company: N/A
# Internship 25 Location: N/A
# Internship 25 Description: ...
# Internship 26 Title: N/A
# Internship 26 Company: N/A
# Internship 26 Location: N/A
# Internship 26 Description: ...
# Internship 27 Title: N/A
# Internship 27 Company: N/A
# Internship 27 Location: N/A
# Internship 27 Description: ...
# Internship 28 Title: N/A
# Internship 28 Company: N/A
# Internship 28 Location: N/A
# Internship 28 Description: ...
# Internship 29 Title: N/A
# Internship 29 Company: N/A
# Internship 29 Location: N/A
# Internship 29 Description: ...
# Internship 30 Title: N/A
# Internship 30 Company: N/A
# Internship 30 Location: N/A
# Internship 30 Description: ...
# Internship 31 Title: N/A
# Internship 31 Company: N/A
# Internship 31 Location: N/A
# Internship 31 Description: ...
# Internship 32 Title: N/A
# Internship 32 Company: N/A
# Internship 32 Location: N/A
# Internship 32 Description: ...
# Internship 33 Title: N/A
# Internship 33 Company: N/A
# Internship 33 Location: N/A
# Internship 33 Description: ...
# Internship 34 Title: N/A
# Internship 34 Company: N/A
# Internship 34 Location: N/A
# Internship 34 Description: ...
# Internship 35 Title: N/A
# Internship 35 Company: N/A
# Internship 35 Location: N/A
# Internship 35 Description: ...
# Internship 36 Title: N/A
# Internship 36 Company: N/A
# Internship 36 Location: N/A
# Internship 36 Description: ...
# Internship 37 Title: N/A
# Internship 37 Company: N/A
# Internship 37 Location: N/A
# Internship 37 Description: ...
# Internship 38 Title: N/A
# Internship 38 Company: N/A
# Internship 38 Location: N/A
# Internship 38 Description: ...
# Internship 39 Title: N/A
# Internship 39 Company: N/A
# Internship 39 Location: N/A
# Internship 39 Description: ...
# Internship 40 Title: N/A
# Internship 40 Company: N/A
# Internship 40 Location: N/A
# Internship 40 Description: ...
# Internship details extracted!

# %%
# Convert list of dictionaries to a DataFrame
df = pd.DataFrame(internships)

# Show the first 5 entries
display(df.head())
# Out:
#   Title Company Location Description
# 0   N/A     N/A      N/A
# 1   N/A     N/A      N/A
# 2   N/A     N/A      N/A
# 3   N/A     N/A      N/A
# 4   N/A     N/A      N/A

# %%
if df.empty:
    print("No internship data available.")
# Out:
# No internship data available.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import time

# %%
url = "https://remoteok.com/remote-data-jobs"
headers = {'User-Agent': 'Mozilla/5.0'}

response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    print("Page fetched successfully!")
else:
    print("Failed to fetch the page.")
# Out:
# Page fetched successfully!

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# Find all job listings
jobs = soup.find_all('tr', class_='job')

print(f"Found {len(jobs)} job listings")
# Out:
# Found 9 job listings

# %%
internships = []

for job in jobs:
    title = job.find('h2', itemprop='title')
    company = job.find('h3', itemprop='name')
    location = job.find('div', class_='location')
    date = job.find('time')

    internships.append({
        "Title": title.text.strip() if title else "N/A",
        "Company": company.text.strip() if company else "N/A",
        "Location": location.text.strip() if location else "Worldwide",
        "Date": date['datetime'].strip() if date else "N/A"
    })

print(f"Extracted {len(internships)} job details")
# Out:
# Extracted 9 job details

# %%
df = pd.DataFrame(internships)

# Show the first few rows
df.head()
# Out:
#   Title Company   Location Date
# 0   N/A     N/A  Worldwide  N/A
# 1   N/A     N/A  Worldwide  N/A
# 2   N/A     N/A  Worldwide  N/A
# 3   N/A     N/A  Worldwide  N/A
# 4   N/A     N/A  Worldwide  N/A

# %% [markdown]
# **Another example**

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import time

# %%
url = "https://remoteok.com/remote-data-jobs"
headers = {'User-Agent': 'Mozilla/5.0'}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    print("Page loaded successfully!")
else:
    print("Failed to load page.")
# Out:
# Page loaded successfully!

# %%
soup = BeautifulSoup(response.content, 'html.parser')

jobs = soup.find_all('tr', class_='job')

print(f"Found {len(jobs)} job listings (including placeholders)")
# Out:
# Found 9 job listings (including placeholders)

# %%
valid_jobs = [job for job in jobs if job.find('h2') and job.find('h3')]

print(f"Found {len(valid_jobs)} valid job listings")
# Out:
# Found 0 valid job listings

# %%
internships = []

for job in valid_jobs:
    title = job.find('h2', itemprop='title')
    company = job.find('h3', itemprop='name')
    location = job.find('div', class_='location')
    date = job.find('time')

    internships.append({
        "Title": title.text.strip() if title else "N/A",
        "Company": company.text.strip() if company else "N/A",
        "Location": location.text.strip() if location else "Worldwide",
        "Date": date['datetime'].strip() if date else "N/A"
    })

# %%
df = pd.DataFrame(internships)

print("Data extracted successfully!")
# Out:
# Data extracted successfully!

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
